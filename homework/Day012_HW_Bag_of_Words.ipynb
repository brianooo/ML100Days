# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %%
whole_words[:50]
# Out:
# ['Wow',
#  '...',
#  'Loved',
#  'this',
#  'place',
#  '.',
#  'Crust',
#  'is',
#  'not',
#  'good',
#  '.',
#  'Not',
#  'tasty',
#  'and',
#  'the',
#  'texture',
#  'was',
#  'just',
#  'nasty',
#  '.',
#  'Stopped',
#  'by',
#  'during',
#  'the',
#  'late',
#  'May',
#  'bank',
#  'holiday',
#  'off',
#  'Rick',
#  'Steve',
#  'recommendation',
#  'and',
#  'loved',
#  'it',
#  '.',
#  'The',
#  'selection',
#  'on',
#  'the',
#  'menu',
#  'was',
#  'great',
#  'and',
#  'so',
#  'were',
#  'the',
#  'prices',
#  '.',
#  'Now']

# %% [markdown]
# ### 移除重複單字

# %%
new_whole = []
for word in whole_words:
    if word in new_whole:
        pass
    else:
        new_whole.append(word)
whole_words = new_whole
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2356個單字

# %%
whole_words[:20]
# Out:
# ['Wow',
#  '...',
#  'Loved',
#  'this',
#  'place',
#  '.',
#  'Crust',
#  'is',
#  'not',
#  'good',
#  'Not',
#  'tasty',
#  'and',
#  'the',
#  'texture',
#  'was',
#  'just',
#  'nasty',
#  'Stopped',
#  'by']

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    index_word[n] = word
    word_index[word] = n
    n += 1

# %%
word_index
# Out:
# {'Wow': 0,
#  '...': 1,
#  'Loved': 2,
#  'this': 3,
#  'place': 4,
#  '.': 5,
#  'Crust': 6,
#  'is': 7,
#  'not': 8,
#  'good': 9,
#  'Not': 10,
#  'tasty': 11,
#  'and': 12,
#  'the': 13,
#  'texture': 14,
#  'was': 15,
#  'just': 16,
#  'nasty': 17,
#  'Stopped': 18,
#  'by': 19,
#  'during': 20,
#  'late': 21,
#  'May': 22,
#  'bank': 23,
#  'holiday': 24,
#  'off': 25,
#  'Rick': 26,
#  'Steve': 27,
#  'recommendation': 28,
#  'loved': 29,
#  'it': 30,
#  'The': 31,
#  'selection': 32,
#  'on': 33,
#  'menu': 34,
#  'great': 35,
#  'so': 36,
#  'were': 37,
#  'prices': 38,
#  'Now': 39,
#  'I': 40,
#  'am': 41,
#  'getting': 42,
#  'angry': 43,
#  'want': 44,
#  'my': 45,
#  'damn': 46,
#  'pho': 47,
#  'Honeslty': 48,
#  'did': 49,
#  "n't": 50,
#  'taste': 51,
#  'THAT': 52,
#  'fresh': 53,
#  ')': 54,
#  'potatoes': 55,
#  'like': 56,
#  'rubber': 57,
#  'you': 58,
#  'could': 59,
#  'tell': 60,
#  'they': 61,
#  'had': 62,
#  'been': 63,
#  'made': 64,
#  'up': 65,
#  'ahead': 66,
#  'of': 67,
#  'time': 68,
#  'being': 69,
#  'kept': 70,
#  'under': 71,
#  'a': 72,
#  'warmer': 73,
#  'fries': 74,
#  'too': 75,
#  'A': 76,
#  'touch': 77,
#  'Service': 78,
#  'very': 79,
#  'prompt': 80,
#  'Would': 81,
#  'go': 82,
#  'back': 83,
#  'cashier': 84,
#  'no': 85,
#  'care': 86,
#  'what': 87,
#  'ever': 88,
#  'to': 89,
#  'say': 90,
#  'still': 91,
#  'ended': 92,
#  'wayyy': 93,
#  'overpriced': 94,
#  'tried': 95,
#  'Cape': 96,
#  'Cod': 97,
#  'ravoli': 98,
#  ',': 99,
#  'chicken': 100,
#  'with': 101,
#  'cranberry': 102,
#  'mmmm': 103,
#  '!': 104,
#  'disgusted': 105,
#  'because': 106,
#  'pretty': 107,
#  'sure': 108,
#  'that': 109,
#  'human': 110,
#  'hair': 111,
#  'shocked': 112,
#  'signs': 113,
#  'indicate': 114,
#  'cash': 115,
#  'only': 116,
#  'Highly': 117,
#  'recommended': 118,
#  'Waitress': 119,
#  'little': 120,
#  'slow': 121,
#  'in': 122,
#  'service': 123,
#  'This': 124,
#  'worth': 125,
#  'your': 126,
#  'let': 127,
#  'alone': 128,
#  'Vegas': 129,
#  'at': 130,
#  'all': 131,
#  'Burrittos': 132,
#  'Blah': 133,
#  'food': 134,
#  'amazing': 135,
#  'also': 136,
#  'cute': 137,
#  'less': 138,
#  'interior': 139,
#  'beautiful': 140,
#  'So': 141,
#  'performed': 142,
#  'That': 143,
#  "'s": 144,
#  'right': 145,
#  '.the': 146,
#  'red': 147,
#  'velvet': 148,
#  'cake': 149,
#  '..ohhh': 150,
#  'stuff': 151,
#  '-': 152,
#  'They': 153,
#  'never': 154,
#  'brought': 155,
#  'salad': 156,
#  'we': 157,
#  'asked': 158,
#  'for': 159,
#  'hole': 160,
#  'wall': 161,
#  'has': 162,
#  'Mexican': 163,
#  'street': 164,
#  'tacos': 165,
#  'friendly': 166,
#  'staff': 167,
#  'Took': 168,
#  'an': 169,
#  'hour': 170,
#  'get': 171,
#  'our': 172,
#  '4': 173,
#  'tables': 174,
#  'restaurant': 175,
#  'Luke': 176,
#  'warm': 177,
#  'Our': 178,
#  'sever': 179,
#  'running': 180,
#  'around': 181,
#  'he': 182,
#  'totally': 183,
#  'overwhelmed': 184,
#  'worst': 185,
#  'salmon': 186,
#  'sashimi': 187,
#  'Also': 188,
#  'there': 189,
#  'are': 190,
#  'combos': 191,
#  'burger': 192,
#  'beer': 193,
#  '23': 194,
#  'which': 195,
#  'decent': 196,
#  'deal': 197,
#  'final': 198,
#  'blow': 199,
#  'found': 200,
#  'accident': 201,
#  'be': 202,
#  'happier': 203,
#  'seems': 204,
#  'quick': 205,
#  'grab': 206,
#  'bite': 207,
#  'some': 208,
#  'familiar': 209,
#  'pub': 210,
#  'but': 211,
#  'do': 212,
#  'yourself': 213,
#  'favor': 214,
#  'look': 215,
#  'elsewhere': 216,
#  'Overall': 217,
#  'lot': 218,
#  'redeeming': 219,
#  'quality': 220,
#  'inexpensive': 221,
#  'Ample': 222,
#  'portions': 223,
#  'Poor': 224,
#  'waiter': 225,
#  'me': 226,
#  'feel': 227,
#  'stupid': 228,
#  'every': 229,
#  'came': 230,
#  'table': 231,
#  'My': 232,
#  'first': 233,
#  'visit': 234,
#  'Hiro': 235,
#  'delight': 236,
#  'sucks': 237,
#  'shrimp': 238,
#  'tender': 239,
#  'moist': 240,
#  'There': 241,
#  'enough': 242,
#  'would': 243,
#  'drag': 244,
#  'into': 245,
#  'establishment': 246,
#  'again': 247,
#  'Hard': 248,
#  'judge': 249,
#  'whether': 250,
#  'these': 251,
#  'sides': 252,
#  'grossed': 253,
#  'out': 254,
#  'melted': 255,
#  'styrofoam': 256,
#  'eat': 257,
#  'fear': 258,
#  'sick': 259,
#  'On': 260,
#  'positive': 261,
#  'note': 262,
#  'server': 263,
#  'attentive': 264,
#  'provided': 265,
#  'Frozen': 266,
#  'pucks': 267,
#  'disgust': 268,
#  'people': 269,
#  'behind': 270,
#  'register': 271,
#  'thing': 272,
#  'prime': 273,
#  'rib': 274,
#  'dessert': 275,
#  'section': 276,
#  'It': 277,
#  'bad': 278,
#  'generic': 279,
#  'beef': 280,
#  'cooked': 281,
#  'If': 282,
#  'sandwich': 283,
#  'any': 284,
#  'Firehouse': 285,
#  'side': 286,
#  'Greek': 287,
#  'dressing': 288,
#  'pita': 289,
#  'hummus': 290,
#  'refreshing': 291,
#  'We': 292,
#  'ordered': 293,
#  'duck': 294,
#  'rare': 295,
#  'pink': 296,
#  'inside': 297,
#  'nice': 298,
#  'char': 299,
#  'outside': 300,
#  'He': 301,
#  'after': 302,
#  'us': 303,
#  'when': 304,
#  'realized': 305,
#  'husband': 306,
#  'left': 307,
#  'his': 308,
#  'sunglasses': 309,
#  'Their': 310,
#  'chow': 311,
#  'mein': 312,
#  'have': 313,
#  'horrible': 314,
#  'attitudes': 315,
#  'towards': 316,
#  'customers': 317,
#  'talk': 318,
#  'down': 319,
#  'each': 320,
#  'one': 321,
#  'enjoy': 322,
#  'their': 323,
#  'portion': 324,
#  'huge': 325,
#  'servers': 326,
#  'wonderful': 327,
#  'imaginative': 328,
#  'Heart': 329,
#  'Attack': 330,
#  'Grill': 331,
#  'downtown': 332,
#  'absolutely': 333,
#  'flat-lined': 334,
#  'excuse': 335,
#  'much': 336,
#  'seafood': 337,
#  '5': 338,
#  'strings': 339,
#  'pasta': 340,
#  'bottom': 341,
#  'amount': 342,
#  'sauce': 343,
#  'over': 344,
#  'power': 345,
#  'scallop': 346,
#  'perfectly': 347,
#  'ripped': 348,
#  'banana': 349,
#  'petrified': 350,
#  'tasteless': 351,
#  'At': 352,
#  'least': 353,
#  'think': 354,
#  'refill': 355,
#  'water': 356,
#  'before': 357,
#  'struggle': 358,
#  'wave': 359,
#  '10': 360,
#  'minutes': 361,
#  'receives': 362,
#  'stars': 363,
#  'APPETIZERS': 364,
#  'cocktails': 365,
#  'handmade': 366,
#  'delicious': 367,
#  "'d": 368,
#  'definitely': 369,
#  'here': 370,
#  'glad': 371,
#  'Great': 372,
#  'give': 373,
#  'military': 374,
#  'discount': 375,
#  'Always': 376,
#  'Dos': 377,
#  'Gringos': 378,
#  'Update': 379,
#  '..went': 380,
#  'second': 381,
#  'as': 382,
#  'got': 383,
#  'apparently': 384,
#  'heard': 385,
#  'salt': 386,
#  'batter': 387,
#  'fish': 388,
#  'chewy': 389,
#  'way': 390,
#  'finish': 391,
#  'included': 392,
#  'tastings': 393,
#  '2': 394,
#  'drinks': 395,
#  'Jeff': 396,
#  'went': 397,
#  'above': 398,
#  'beyond': 399,
#  'expected': 400,
#  'Really': 401,
#  'really': 402,
#  'rice': 403,
#  'meh': 404,
#  'took': 405,
#  '30': 406,
#  'min': 407,
#  'milkshake': 408,
#  'nothing': 409,
#  'more': 410,
#  'than': 411,
#  'chocolate': 412,
#  'milk': 413,
#  'guess': 414,
#  'should': 415,
#  'known': 416,
#  'suck': 417,
#  'Excalibur': 418,
#  'use': 419,
#  'common': 420,
#  'sense': 421,
#  'dish': 422,
#  'quite': 423,
#  'appalling': 424,
#  'value': 425,
#  'well': 426,
#  'times': 427,
#  'Very': 428,
#  'Bad': 429,
#  'Customer': 430,
#  'sweet': 431,
#  'potato': 432,
#  'seasoned': 433,
#  'Today': 434,
#  "'ve": 435,
#  'lunch': 436,
#  'buffet': 437,
#  'cheated': 438,
#  'wasting': 439,
#  'eating': 440,
#  'opportunity': 441,
#  'going': 442,
#  'Rice': 443,
#  'Company': 444,
#  'Coming': 445,
#  'experiencing': 446,
#  'underwhelming': 447,
#  'relationship': 448,
#  'where': 449,
#  'both': 450,
#  'parties': 451,
#  'ca': 452,
#  'wait': 453,
#  'other': 454,
#  'person': 455,
#  'ask': 456,
#  'break': 457,
#  'walked': 458,
#  'smelled': 459,
#  'old': 460,
#  'grease': 461,
#  'trap': 462,
#  'others': 463,
#  'turkey': 464,
#  'roast': 465,
#  'bland': 466,
#  'pan': 467,
#  'cakes': 468,
#  'everyone': 469,
#  'raving': 470,
#  'about': 471,
#  'sugary': 472,
#  'disaster': 473,
#  'tailored': 474,
#  'palate': 475,
#  'six': 476,
#  'year': 477,
#  'love': 478,
#  'Pho': 479,
#  'spring': 480,
#  'rolls': 481,
#  'oh': 482,
#  'yummy': 483,
#  'try': 484,
#  'poor': 485,
#  'meat': 486,
#  'ratio': 487,
#  'tenders': 488,
#  'unsatisfying': 489,
#  'All': 490,
#  'Omelets': 491,
#  'die': 492,
#  'Everything': 493,
#  'In': 494,
#  'summary': 495,
#  'largely': 496,
#  'disappointing': 497,
#  'dining': 498,
#  'experience': 499,
#  'sexy': 500,
#  'party': 501,
#  'mouth': 502,
#  "'re": 503,
#  'outrageously': 504,
#  'flirting': 505,
#  'hottest': 506,
#  'Never': 507,
#  'Rock': 508,
#  'Casino': 509,
#  'WILL': 510,
#  'NEVER': 511,
#  'EVER': 512,
#  'STEP': 513,
#  'FORWARD': 514,
#  'IN': 515,
#  'IT': 516,
#  'AGAIN': 517,
#  'Best': 518,
#  'breakfast': 519,
#  'bye': 520,
#  'tip': 521,
#  'lady': 522,
#  "'ll": 523,
#  'Will': 524,
#  'Food': 525,
#  'arrived': 526,
#  'quickly': 527,
#  'cafe': 528,
#  'serves': 529,
#  'fantastic': 530,
#  'wife': 531,
#  'loves': 532,
#  'roasted': 533,
#  'garlic': 534,
#  'bone': 535,
#  'marrow': 536,
#  'added': 537,
#  'extra': 538,
#  'meal': 539,
#  'another': 540,
#  'helpful': 541,
#  'bloddy': 542,
#  'mary': 543,
#  'coming': 544,
#  'Buffet': 545,
#  'town': 546,
#  'price': 547,
#  'can': 548,
#  'beat': 549,
#  'LOVED': 550,
#  'mussels': 551,
#  'wine': 552,
#  'reduction': 553,
#  'dishes': 554,
#  'better': 555,
#  'buffets': 556,
#  'Tigerlilly': 557,
#  'afternoon': 558,
#  'bartender': 559,
#  'personable': 560,
#  'AND': 561,
#  'ambience': 562,
#  'music': 563,
#  'playing': 564,
#  'next': 565,
#  'trip': 566,
#  'Sooooo': 567,
#  'REAL': 568,
#  'sushi': 569,
#  'lovers': 570,
#  'honest': 571,
#  'Yama': 572,
#  '40min': 573,
#  'passed': 574,
#  'between': 575,
#  'ordering': 576,
#  'arriving': 577,
#  'busy': 578,
#  'Thai': 579,
#  'Nice': 580,
#  'spicy': 581,
#  'Good': 582,
#  'Check': 583,
#  'gross': 584,
#  'atmosphere': 585,
#  'Kind': 586,
#  'hard': 587,
#  'mess': 588,
#  'steak': 589,
#  'Although': 590,
#  'liked': 591,
#  'sound': 592,
#  'actual': 593,
#  'bit': 594,
#  'know': 595,
#  'how': 596,
#  'managed': 597,
#  'served': 598,
#  'blandest': 599,
#  'eaten': 600,
#  'preparing': 601,
#  'Indian': 602,
#  'cuisine': 603,
#  'Worst': 604,
#  'boot': 605,
#  'worries': 606,
#  'fine': 607,
#  'waitress': 608,
#  'guys': 609,
#  'steaks': 610,
#  'loving': 611,
#  'son': 612,
#  'who': 613,
#  'best': 614,
#  'places': 615,
#  'said': 616,
#  'thought': 617,
#  'venture': 618,
#  'further': 619,
#  'away': 620,
#  'hit': 621,
#  'spot': 622,
#  'night': 623,
#  'Host': 624,
#  'lack': 625,
#  'word': 626,
#  'BITCHES': 627,
#  'Bland': 628,
#  'liking': 629,
#  'number': 630,
#  'reasons': 631,
#  'waste': 632,
#  'reviewing..': 633,
#  'leave': 634,
#  'Phenomenal': 635,
#  'ambiance': 636,
#  'return': 637,
#  'Definitely': 638,
#  'venturing': 639,
#  'strip': 640,
#  'pork': 641,
#  'belly': 642,
#  'will': 643,
#  "'m": 644,
#  'mediocre': 645,
#  'Penne': 646,
#  'vodka': 647,
#  'excellent': 648,
#  'including': 649,
#  'massive': 650,
#  'meatloaf': 651,
#  'crispy': 652,
#  'wrap': 653,
#  'delish': 654,
#  'tuna': 655,
#  'melt': 656,
#  'burgers': 657,
#  'management': 658,
#  'rude': 659,
#  'Delicious': 660,
#  'NYC': 661,
#  'bagels': 662,
#  'selections': 663,
#  'cream': 664,
#  'cheese': 665,
#  'real': 666,
#  'Lox': 667,
#  'capers': 668,
#  'even': 669,
#  'Subway': 670,
#  'fact': 671,
#  'come': 672,
#  'meet': 673,
#  'expectations': 674,
#  'seriously': 675,
#  'solid': 676,
#  'bars': 677,
#  'extremely': 678,
#  'many': 679,
#  'restaurants': 680,
#  'dine': 681,
#  'weekend': 682,
#  'drink': 683,
#  'empty': 684,
#  'suggestions': 685,
#  'Do': 686,
#  'or': 687,
#  'rarely': 688,
#  'checked': 689,
#  'ate': 690,
#  'disappointed': 691,
#  'And': 692,
#  'curry': 693,
#  'bamboo': 694,
#  'shoots': 695,
#  'blanket': 696,
#  'moz': 697,
#  'top': 698,
#  'i': 699,
#  'done': 700,
#  'cover': 701,
#  'subpar': 702,
#  'bathrooms': 703,
#  'clean': 704,
#  'itself': 705,
#  'decorated': 706,
#  'always': 707,
#  'changing': 708,
#  '&': 709,
#  'considering': 710,
#  '3': 711,
#  'pace': 712,
#  'thumbs': 713,
#  'watched': 714,
#  'pay': 715,
#  'attention': 716,
#  'ignore': 717,
#  'fiancé': 718,
#  'middle': 719,
#  'day': 720,
#  'greeted': 721,
#  'seated': 722,
#  'Mandalay': 723,
#  'Bay': 724,
#  'waited': 725,
#  'forty': 726,
#  'five': 727,
#  'vain': 728,
#  'Crostini': 729,
#  'stale': 730,
#  'Some': 731,
#  'highlights': 732,
#  ':': 733,
#  'nigiri': 734,
#  'joint': 735,
#  'different': 736,
#  'cut': 737,
#  'piece': 738,
#  's': 739,
#  'flavored': 740,
#  'Voodoo': 741,
#  'since': 742,
#  'gluten': 743,
#  'free': 744,
#  'several': 745,
#  'years': 746,
#  'ago': 747,
#  'Unfortunately': 748,
#  'must': 749,
#  'bakery': 750,
#  'leftover': 751,
#  'everything': 752,
#  'STALE': 753,
#  'today': 754,
#  'relocated': 755,
#  'impressed': 756,
#  'immediately': 757,
#  'diverse': 758,
#  'reasonably': 759,
#  'priced': 760,
#  'Avoid': 761,
#  'cost': 762,
#  'Restaurant': 763,
#  'full': 764,
#  'DELICIOUS': 765,
#  'hands-down': 766,
#  'Phoenix': 767,
#  'metro': 768,
#  'area': 769,
#  'if': 770,
#  'looking': 771,
#  'treated': 772,
#  'Bacon': 773,
#  'hella': 774,
#  'salty': 775,
#  'spinach': 776,
#  'avocado': 777,
#  'ingredients': 778,
#  'sad': 779,
#  'literally': 780,
#  'zero': 781,
#  'used': 782,
#  'menus': 783,
#  'handed': 784,
#  'ladies': 785,
#  'listed': 786,
#  'waitresses': 787,
#  'Lordy': 788,
#  'Khao': 789,
#  'Soi': 790,
#  'missed': 791,
#  'terrific': 792,
#  'thrilled': 793,
#  'accommodations': 794,
#  'vegetarian': 795,
#  'daughter': 796,
#  'Perhaps': 797,
#  'caught': 798,
#  'them': 799,
#  'judging': 800,
#  'reviews': 801,
#  'inspired': 802,
#  'leaves': 803,
#  'desired': 804,
#  'modern': 805,
#  'hip': 806,
#  'while': 807,
#  'maintaining': 808,
#  'coziness': 809,
#  'weekly': 810,
#  'haunt': 811,
#  'once': 812,
#  'sat': 813,
#  '20': 814,
#  'asking': 815,
#  'take': 816,
#  'order': 817,
#  'flavor': 818,
#  'overcooked': 819,
#  'charcoal': 820,
#  'decided': 821,
#  'send': 822,
#  'looked': 823,
#  'she': 824,
#  'verge': 825,
#  'having': 826,
#  'heart': 827,
#  'attack': 828,
#  'dressed': 829,
#  'rudely': 830,
#  'probably': 831,
#  'dirt': 832,
#  'Love': 833,
#  'hits': 834,
#  'something': 835,
#  'healthy': 836,
#  'lacking': 837,
#  'quantity': 838,
#  'Lemon': 839,
#  'raspberry': 840,
#  'ice': 841,
#  'cocktail': 842,
#  'incredible': 843,
#  'sucked': 844,
#  'imagined': 845,
#  'Interesting': 846,
#  'decor': 847,
#  'What': 848,
#  'crepe': 849,
#  'station': 850,
#  'hot': 851,
#  'bread': 852,
#  'butter': 853,
#  'home': 854,
#  'chips': 855,
#  'bacon': 856,
#  'bits': 857,
#  '.very': 858,
#  'original': 859,
#  'watch': 860,
#  'Both': 861,
#  'egg': 862,
#  'When': 863,
#  'gyros': 864,
#  'missing': 865,
#  'wings': 866,
#  'feeling': 867,
#  'satisfied': 868,
#  'Joey': 869,
#  'voted': 870,
#  'dog': 871,
#  'Valley': 872,
#  'readers': 873,
#  'Magazine': 874,
#  'bowl': 875,
#  'live': 876,
#  'Fridays': 877,
#  'blows': 878,
#  'insulted': 879,
#  'felt': 880,
#  'disrespected': 881,
#  'drive': 882,
#  'things': 883,
#  'exceeding': 884,
#  'hope': 885,
#  'dreamed': 886,
#  'serivce': 887,
#  'help': 888,
#  'brunch': 889,
#  'inviting': 890,
#  'lived': 891,
#  '1979': 892,
#  '(': 893,
#  'last': 894,
#  'stepped': 895,
#  'foot': 896,
#  'WORST': 897,
#  'EXPERIENCE': 898,
#  'Must': 899,
#  'mixed': 900,
#  'mushrooms': 901,
#  'yukon': 902,
#  'gold': 903,
#  'puree': 904,
#  'white': 905,
#  'corn': 906,
#  'beateous': 907,
#  'bug': 908,
#  'showed': 909,
#  'given': 910,
#  'climbing': 911,
#  'kitchen': 912,
#  'For': 913,
#  'waiting': 914,
#  'her': 915,
#  'soon': 916,
#  'friend': 917,
#  'tartar': 918,
#  'Wo': 919,
#  'Extremely': 920,
#  'Tasty': 921,
#  'though': 922,
#  'Soggy': 923,
#  'Jamaican': 924,
#  'mojitos': 925,
#  'Which': 926,
#  'small': 927,
#  'rich': 928,
#  'accordingly': 929,
#  'shower': 930,
#  'rinse': 931,
#  'unless': 932,
#  'mind': 933,
#  'nude': 934,
#  'see': 935,
#  'Lobster': 936,
#  'Bisque': 937,
#  'Bussell': 938,
#  'Sprouts': 939,
#  'Risotto': 940,
#  'Filet': 941,
#  'ALL': 942,
#  'needed': 943,
#  'pepper..and': 944,
#  'course': 945,
#  'none': 946,
#  'Hopefully': 947,
#  'bodes': 948,
#  'business': 949,
#  'someone': 950,
#  'cook': 951,
#  'either': 952,
#  'cold': 953,
#  'wrapped': 954,
#  'dates': 955,
#  'unbelievable': 956,
#  'BARGAIN': 957,
#  'folks': 958,
#  'Otto': 959,
#  'make': 960,
#  'welcome': 961,
#  'special': 962,
#  'As': 963,
#  '``': 964,
#  'mains': 965,
#  "''": 966,
#  'uninspired': 967,
#  'must-stop': 968,
#  'whenever': 969,
#  'then': 970,
#  'dealing': 971,
#  'world': 972,
#  'worst/annoying': 973,
#  'drunk': 974,
#  'fun': 975,
#  'chef': 976,
#  'Ordered': 977,
#  'double': 978,
#  'cheeseburger': 979,
#  'single': 980,
#  'patty': 981,
#  'falling': 982,
#  'apart': 983,
#  'picture': 984,
#  'uploaded': 985,
#  'Yeah': 986,
#  'couple': 987,
#  'sporting': 988,
#  'events': 989,
#  'walls': 990,
#  'covered': 991,
#  'TV': 992,
#  'possible': 993,
#  'descriptions': 994,
#  'yum': 995,
#  'eel': 996,
#  'yet': 997,
#  'mayo': 998,
#  'NONE': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'Wow',
#  1: '...',
#  2: 'Loved',
#  3: 'this',
#  4: 'place',
#  5: '.',
#  6: 'Crust',
#  7: 'is',
#  8: 'not',
#  9: 'good',
#  10: 'Not',
#  11: 'tasty',
#  12: 'and',
#  13: 'the',
#  14: 'texture',
#  15: 'was',
#  16: 'just',
#  17: 'nasty',
#  18: 'Stopped',
#  19: 'by',
#  20: 'during',
#  21: 'late',
#  22: 'May',
#  23: 'bank',
#  24: 'holiday',
#  25: 'off',
#  26: 'Rick',
#  27: 'Steve',
#  28: 'recommendation',
#  29: 'loved',
#  30: 'it',
#  31: 'The',
#  32: 'selection',
#  33: 'on',
#  34: 'menu',
#  35: 'great',
#  36: 'so',
#  37: 'were',
#  38: 'prices',
#  39: 'Now',
#  40: 'I',
#  41: 'am',
#  42: 'getting',
#  43: 'angry',
#  44: 'want',
#  45: 'my',
#  46: 'damn',
#  47: 'pho',
#  48: 'Honeslty',
#  49: 'did',
#  50: "n't",
#  51: 'taste',
#  52: 'THAT',
#  53: 'fresh',
#  54: ')',
#  55: 'potatoes',
#  56: 'like',
#  57: 'rubber',
#  58: 'you',
#  59: 'could',
#  60: 'tell',
#  61: 'they',
#  62: 'had',
#  63: 'been',
#  64: 'made',
#  65: 'up',
#  66: 'ahead',
#  67: 'of',
#  68: 'time',
#  69: 'being',
#  70: 'kept',
#  71: 'under',
#  72: 'a',
#  73: 'warmer',
#  74: 'fries',
#  75: 'too',
#  76: 'A',
#  77: 'touch',
#  78: 'Service',
#  79: 'very',
#  80: 'prompt',
#  81: 'Would',
#  82: 'go',
#  83: 'back',
#  84: 'cashier',
#  85: 'no',
#  86: 'care',
#  87: 'what',
#  88: 'ever',
#  89: 'to',
#  90: 'say',
#  91: 'still',
#  92: 'ended',
#  93: 'wayyy',
#  94: 'overpriced',
#  95: 'tried',
#  96: 'Cape',
#  97: 'Cod',
#  98: 'ravoli',
#  99: ',',
#  100: 'chicken',
#  101: 'with',
#  102: 'cranberry',
#  103: 'mmmm',
#  104: '!',
#  105: 'disgusted',
#  106: 'because',
#  107: 'pretty',
#  108: 'sure',
#  109: 'that',
#  110: 'human',
#  111: 'hair',
#  112: 'shocked',
#  113: 'signs',
#  114: 'indicate',
#  115: 'cash',
#  116: 'only',
#  117: 'Highly',
#  118: 'recommended',
#  119: 'Waitress',
#  120: 'little',
#  121: 'slow',
#  122: 'in',
#  123: 'service',
#  124: 'This',
#  125: 'worth',
#  126: 'your',
#  127: 'let',
#  128: 'alone',
#  129: 'Vegas',
#  130: 'at',
#  131: 'all',
#  132: 'Burrittos',
#  133: 'Blah',
#  134: 'food',
#  135: 'amazing',
#  136: 'also',
#  137: 'cute',
#  138: 'less',
#  139: 'interior',
#  140: 'beautiful',
#  141: 'So',
#  142: 'performed',
#  143: 'That',
#  144: "'s",
#  145: 'right',
#  146: '.the',
#  147: 'red',
#  148: 'velvet',
#  149: 'cake',
#  150: '..ohhh',
#  151: 'stuff',
#  152: '-',
#  153: 'They',
#  154: 'never',
#  155: 'brought',
#  156: 'salad',
#  157: 'we',
#  158: 'asked',
#  159: 'for',
#  160: 'hole',
#  161: 'wall',
#  162: 'has',
#  163: 'Mexican',
#  164: 'street',
#  165: 'tacos',
#  166: 'friendly',
#  167: 'staff',
#  168: 'Took',
#  169: 'an',
#  170: 'hour',
#  171: 'get',
#  172: 'our',
#  173: '4',
#  174: 'tables',
#  175: 'restaurant',
#  176: 'Luke',
#  177: 'warm',
#  178: 'Our',
#  179: 'sever',
#  180: 'running',
#  181: 'around',
#  182: 'he',
#  183: 'totally',
#  184: 'overwhelmed',
#  185: 'worst',
#  186: 'salmon',
#  187: 'sashimi',
#  188: 'Also',
#  189: 'there',
#  190: 'are',
#  191: 'combos',
#  192: 'burger',
#  193: 'beer',
#  194: '23',
#  195: 'which',
#  196: 'decent',
#  197: 'deal',
#  198: 'final',
#  199: 'blow',
#  200: 'found',
#  201: 'accident',
#  202: 'be',
#  203: 'happier',
#  204: 'seems',
#  205: 'quick',
#  206: 'grab',
#  207: 'bite',
#  208: 'some',
#  209: 'familiar',
#  210: 'pub',
#  211: 'but',
#  212: 'do',
#  213: 'yourself',
#  214: 'favor',
#  215: 'look',
#  216: 'elsewhere',
#  217: 'Overall',
#  218: 'lot',
#  219: 'redeeming',
#  220: 'quality',
#  221: 'inexpensive',
#  222: 'Ample',
#  223: 'portions',
#  224: 'Poor',
#  225: 'waiter',
#  226: 'me',
#  227: 'feel',
#  228: 'stupid',
#  229: 'every',
#  230: 'came',
#  231: 'table',
#  232: 'My',
#  233: 'first',
#  234: 'visit',
#  235: 'Hiro',
#  236: 'delight',
#  237: 'sucks',
#  238: 'shrimp',
#  239: 'tender',
#  240: 'moist',
#  241: 'There',
#  242: 'enough',
#  243: 'would',
#  244: 'drag',
#  245: 'into',
#  246: 'establishment',
#  247: 'again',
#  248: 'Hard',
#  249: 'judge',
#  250: 'whether',
#  251: 'these',
#  252: 'sides',
#  253: 'grossed',
#  254: 'out',
#  255: 'melted',
#  256: 'styrofoam',
#  257: 'eat',
#  258: 'fear',
#  259: 'sick',
#  260: 'On',
#  261: 'positive',
#  262: 'note',
#  263: 'server',
#  264: 'attentive',
#  265: 'provided',
#  266: 'Frozen',
#  267: 'pucks',
#  268: 'disgust',
#  269: 'people',
#  270: 'behind',
#  271: 'register',
#  272: 'thing',
#  273: 'prime',
#  274: 'rib',
#  275: 'dessert',
#  276: 'section',
#  277: 'It',
#  278: 'bad',
#  279: 'generic',
#  280: 'beef',
#  281: 'cooked',
#  282: 'If',
#  283: 'sandwich',
#  284: 'any',
#  285: 'Firehouse',
#  286: 'side',
#  287: 'Greek',
#  288: 'dressing',
#  289: 'pita',
#  290: 'hummus',
#  291: 'refreshing',
#  292: 'We',
#  293: 'ordered',
#  294: 'duck',
#  295: 'rare',
#  296: 'pink',
#  297: 'inside',
#  298: 'nice',
#  299: 'char',
#  300: 'outside',
#  301: 'He',
#  302: 'after',
#  303: 'us',
#  304: 'when',
#  305: 'realized',
#  306: 'husband',
#  307: 'left',
#  308: 'his',
#  309: 'sunglasses',
#  310: 'Their',
#  311: 'chow',
#  312: 'mein',
#  313: 'have',
#  314: 'horrible',
#  315: 'attitudes',
#  316: 'towards',
#  317: 'customers',
#  318: 'talk',
#  319: 'down',
#  320: 'each',
#  321: 'one',
#  322: 'enjoy',
#  323: 'their',
#  324: 'portion',
#  325: 'huge',
#  326: 'servers',
#  327: 'wonderful',
#  328: 'imaginative',
#  329: 'Heart',
#  330: 'Attack',
#  331: 'Grill',
#  332: 'downtown',
#  333: 'absolutely',
#  334: 'flat-lined',
#  335: 'excuse',
#  336: 'much',
#  337: 'seafood',
#  338: '5',
#  339: 'strings',
#  340: 'pasta',
#  341: 'bottom',
#  342: 'amount',
#  343: 'sauce',
#  344: 'over',
#  345: 'power',
#  346: 'scallop',
#  347: 'perfectly',
#  348: 'ripped',
#  349: 'banana',
#  350: 'petrified',
#  351: 'tasteless',
#  352: 'At',
#  353: 'least',
#  354: 'think',
#  355: 'refill',
#  356: 'water',
#  357: 'before',
#  358: 'struggle',
#  359: 'wave',
#  360: '10',
#  361: 'minutes',
#  362: 'receives',
#  363: 'stars',
#  364: 'APPETIZERS',
#  365: 'cocktails',
#  366: 'handmade',
#  367: 'delicious',
#  368: "'d",
#  369: 'definitely',
#  370: 'here',
#  371: 'glad',
#  372: 'Great',
#  373: 'give',
#  374: 'military',
#  375: 'discount',
#  376: 'Always',
#  377: 'Dos',
#  378: 'Gringos',
#  379: 'Update',
#  380: '..went',
#  381: 'second',
#  382: 'as',
#  383: 'got',
#  384: 'apparently',
#  385: 'heard',
#  386: 'salt',
#  387: 'batter',
#  388: 'fish',
#  389: 'chewy',
#  390: 'way',
#  391: 'finish',
#  392: 'included',
#  393: 'tastings',
#  394: '2',
#  395: 'drinks',
#  396: 'Jeff',
#  397: 'went',
#  398: 'above',
#  399: 'beyond',
#  400: 'expected',
#  401: 'Really',
#  402: 'really',
#  403: 'rice',
#  404: 'meh',
#  405: 'took',
#  406: '30',
#  407: 'min',
#  408: 'milkshake',
#  409: 'nothing',
#  410: 'more',
#  411: 'than',
#  412: 'chocolate',
#  413: 'milk',
#  414: 'guess',
#  415: 'should',
#  416: 'known',
#  417: 'suck',
#  418: 'Excalibur',
#  419: 'use',
#  420: 'common',
#  421: 'sense',
#  422: 'dish',
#  423: 'quite',
#  424: 'appalling',
#  425: 'value',
#  426: 'well',
#  427: 'times',
#  428: 'Very',
#  429: 'Bad',
#  430: 'Customer',
#  431: 'sweet',
#  432: 'potato',
#  433: 'seasoned',
#  434: 'Today',
#  435: "'ve",
#  436: 'lunch',
#  437: 'buffet',
#  438: 'cheated',
#  439: 'wasting',
#  440: 'eating',
#  441: 'opportunity',
#  442: 'going',
#  443: 'Rice',
#  444: 'Company',
#  445: 'Coming',
#  446: 'experiencing',
#  447: 'underwhelming',
#  448: 'relationship',
#  449: 'where',
#  450: 'both',
#  451: 'parties',
#  452: 'ca',
#  453: 'wait',
#  454: 'other',
#  455: 'person',
#  456: 'ask',
#  457: 'break',
#  458: 'walked',
#  459: 'smelled',
#  460: 'old',
#  461: 'grease',
#  462: 'trap',
#  463: 'others',
#  464: 'turkey',
#  465: 'roast',
#  466: 'bland',
#  467: 'pan',
#  468: 'cakes',
#  469: 'everyone',
#  470: 'raving',
#  471: 'about',
#  472: 'sugary',
#  473: 'disaster',
#  474: 'tailored',
#  475: 'palate',
#  476: 'six',
#  477: 'year',
#  478: 'love',
#  479: 'Pho',
#  480: 'spring',
#  481: 'rolls',
#  482: 'oh',
#  483: 'yummy',
#  484: 'try',
#  485: 'poor',
#  486: 'meat',
#  487: 'ratio',
#  488: 'tenders',
#  489: 'unsatisfying',
#  490: 'All',
#  491: 'Omelets',
#  492: 'die',
#  493: 'Everything',
#  494: 'In',
#  495: 'summary',
#  496: 'largely',
#  497: 'disappointing',
#  498: 'dining',
#  499: 'experience',
#  500: 'sexy',
#  501: 'party',
#  502: 'mouth',
#  503: "'re",
#  504: 'outrageously',
#  505: 'flirting',
#  506: 'hottest',
#  507: 'Never',
#  508: 'Rock',
#  509: 'Casino',
#  510: 'WILL',
#  511: 'NEVER',
#  512: 'EVER',
#  513: 'STEP',
#  514: 'FORWARD',
#  515: 'IN',
#  516: 'IT',
#  517: 'AGAIN',
#  518: 'Best',
#  519: 'breakfast',
#  520: 'bye',
#  521: 'tip',
#  522: 'lady',
#  523: "'ll",
#  524: 'Will',
#  525: 'Food',
#  526: 'arrived',
#  527: 'quickly',
#  528: 'cafe',
#  529: 'serves',
#  530: 'fantastic',
#  531: 'wife',
#  532: 'loves',
#  533: 'roasted',
#  534: 'garlic',
#  535: 'bone',
#  536: 'marrow',
#  537: 'added',
#  538: 'extra',
#  539: 'meal',
#  540: 'another',
#  541: 'helpful',
#  542: 'bloddy',
#  543: 'mary',
#  544: 'coming',
#  545: 'Buffet',
#  546: 'town',
#  547: 'price',
#  548: 'can',
#  549: 'beat',
#  550: 'LOVED',
#  551: 'mussels',
#  552: 'wine',
#  553: 'reduction',
#  554: 'dishes',
#  555: 'better',
#  556: 'buffets',
#  557: 'Tigerlilly',
#  558: 'afternoon',
#  559: 'bartender',
#  560: 'personable',
#  561: 'AND',
#  562: 'ambience',
#  563: 'music',
#  564: 'playing',
#  565: 'next',
#  566: 'trip',
#  567: 'Sooooo',
#  568: 'REAL',
#  569: 'sushi',
#  570: 'lovers',
#  571: 'honest',
#  572: 'Yama',
#  573: '40min',
#  574: 'passed',
#  575: 'between',
#  576: 'ordering',
#  577: 'arriving',
#  578: 'busy',
#  579: 'Thai',
#  580: 'Nice',
#  581: 'spicy',
#  582: 'Good',
#  583: 'Check',
#  584: 'gross',
#  585: 'atmosphere',
#  586: 'Kind',
#  587: 'hard',
#  588: 'mess',
#  589: 'steak',
#  590: 'Although',
#  591: 'liked',
#  592: 'sound',
#  593: 'actual',
#  594: 'bit',
#  595: 'know',
#  596: 'how',
#  597: 'managed',
#  598: 'served',
#  599: 'blandest',
#  600: 'eaten',
#  601: 'preparing',
#  602: 'Indian',
#  603: 'cuisine',
#  604: 'Worst',
#  605: 'boot',
#  606: 'worries',
#  607: 'fine',
#  608: 'waitress',
#  609: 'guys',
#  610: 'steaks',
#  611: 'loving',
#  612: 'son',
#  613: 'who',
#  614: 'best',
#  615: 'places',
#  616: 'said',
#  617: 'thought',
#  618: 'venture',
#  619: 'further',
#  620: 'away',
#  621: 'hit',
#  622: 'spot',
#  623: 'night',
#  624: 'Host',
#  625: 'lack',
#  626: 'word',
#  627: 'BITCHES',
#  628: 'Bland',
#  629: 'liking',
#  630: 'number',
#  631: 'reasons',
#  632: 'waste',
#  633: 'reviewing..',
#  634: 'leave',
#  635: 'Phenomenal',
#  636: 'ambiance',
#  637: 'return',
#  638: 'Definitely',
#  639: 'venturing',
#  640: 'strip',
#  641: 'pork',
#  642: 'belly',
#  643: 'will',
#  644: "'m",
#  645: 'mediocre',
#  646: 'Penne',
#  647: 'vodka',
#  648: 'excellent',
#  649: 'including',
#  650: 'massive',
#  651: 'meatloaf',
#  652: 'crispy',
#  653: 'wrap',
#  654: 'delish',
#  655: 'tuna',
#  656: 'melt',
#  657: 'burgers',
#  658: 'management',
#  659: 'rude',
#  660: 'Delicious',
#  661: 'NYC',
#  662: 'bagels',
#  663: 'selections',
#  664: 'cream',
#  665: 'cheese',
#  666: 'real',
#  667: 'Lox',
#  668: 'capers',
#  669: 'even',
#  670: 'Subway',
#  671: 'fact',
#  672: 'come',
#  673: 'meet',
#  674: 'expectations',
#  675: 'seriously',
#  676: 'solid',
#  677: 'bars',
#  678: 'extremely',
#  679: 'many',
#  680: 'restaurants',
#  681: 'dine',
#  682: 'weekend',
#  683: 'drink',
#  684: 'empty',
#  685: 'suggestions',
#  686: 'Do',
#  687: 'or',
#  688: 'rarely',
#  689: 'checked',
#  690: 'ate',
#  691: 'disappointed',
#  692: 'And',
#  693: 'curry',
#  694: 'bamboo',
#  695: 'shoots',
#  696: 'blanket',
#  697: 'moz',
#  698: 'top',
#  699: 'i',
#  700: 'done',
#  701: 'cover',
#  702: 'subpar',
#  703: 'bathrooms',
#  704: 'clean',
#  705: 'itself',
#  706: 'decorated',
#  707: 'always',
#  708: 'changing',
#  709: '&',
#  710: 'considering',
#  711: '3',
#  712: 'pace',
#  713: 'thumbs',
#  714: 'watched',
#  715: 'pay',
#  716: 'attention',
#  717: 'ignore',
#  718: 'fiancé',
#  719: 'middle',
#  720: 'day',
#  721: 'greeted',
#  722: 'seated',
#  723: 'Mandalay',
#  724: 'Bay',
#  725: 'waited',
#  726: 'forty',
#  727: 'five',
#  728: 'vain',
#  729: 'Crostini',
#  730: 'stale',
#  731: 'Some',
#  732: 'highlights',
#  733: ':',
#  734: 'nigiri',
#  735: 'joint',
#  736: 'different',
#  737: 'cut',
#  738: 'piece',
#  739: 's',
#  740: 'flavored',
#  741: 'Voodoo',
#  742: 'since',
#  743: 'gluten',
#  744: 'free',
#  745: 'several',
#  746: 'years',
#  747: 'ago',
#  748: 'Unfortunately',
#  749: 'must',
#  750: 'bakery',
#  751: 'leftover',
#  752: 'everything',
#  753: 'STALE',
#  754: 'today',
#  755: 'relocated',
#  756: 'impressed',
#  757: 'immediately',
#  758: 'diverse',
#  759: 'reasonably',
#  760: 'priced',
#  761: 'Avoid',
#  762: 'cost',
#  763: 'Restaurant',
#  764: 'full',
#  765: 'DELICIOUS',
#  766: 'hands-down',
#  767: 'Phoenix',
#  768: 'metro',
#  769: 'area',
#  770: 'if',
#  771: 'looking',
#  772: 'treated',
#  773: 'Bacon',
#  774: 'hella',
#  775: 'salty',
#  776: 'spinach',
#  777: 'avocado',
#  778: 'ingredients',
#  779: 'sad',
#  780: 'literally',
#  781: 'zero',
#  782: 'used',
#  783: 'menus',
#  784: 'handed',
#  785: 'ladies',
#  786: 'listed',
#  787: 'waitresses',
#  788: 'Lordy',
#  789: 'Khao',
#  790: 'Soi',
#  791: 'missed',
#  792: 'terrific',
#  793: 'thrilled',
#  794: 'accommodations',
#  795: 'vegetarian',
#  796: 'daughter',
#  797: 'Perhaps',
#  798: 'caught',
#  799: 'them',
#  800: 'judging',
#  801: 'reviews',
#  802: 'inspired',
#  803: 'leaves',
#  804: 'desired',
#  805: 'modern',
#  806: 'hip',
#  807: 'while',
#  808: 'maintaining',
#  809: 'coziness',
#  810: 'weekly',
#  811: 'haunt',
#  812: 'once',
#  813: 'sat',
#  814: '20',
#  815: 'asking',
#  816: 'take',
#  817: 'order',
#  818: 'flavor',
#  819: 'overcooked',
#  820: 'charcoal',
#  821: 'decided',
#  822: 'send',
#  823: 'looked',
#  824: 'she',
#  825: 'verge',
#  826: 'having',
#  827: 'heart',
#  828: 'attack',
#  829: 'dressed',
#  830: 'rudely',
#  831: 'probably',
#  832: 'dirt',
#  833: 'Love',
#  834: 'hits',
#  835: 'something',
#  836: 'healthy',
#  837: 'lacking',
#  838: 'quantity',
#  839: 'Lemon',
#  840: 'raspberry',
#  841: 'ice',
#  842: 'cocktail',
#  843: 'incredible',
#  844: 'sucked',
#  845: 'imagined',
#  846: 'Interesting',
#  847: 'decor',
#  848: 'What',
#  849: 'crepe',
#  850: 'station',
#  851: 'hot',
#  852: 'bread',
#  853: 'butter',
#  854: 'home',
#  855: 'chips',
#  856: 'bacon',
#  857: 'bits',
#  858: '.very',
#  859: 'original',
#  860: 'watch',
#  861: 'Both',
#  862: 'egg',
#  863: 'When',
#  864: 'gyros',
#  865: 'missing',
#  866: 'wings',
#  867: 'feeling',
#  868: 'satisfied',
#  869: 'Joey',
#  870: 'voted',
#  871: 'dog',
#  872: 'Valley',
#  873: 'readers',
#  874: 'Magazine',
#  875: 'bowl',
#  876: 'live',
#  877: 'Fridays',
#  878: 'blows',
#  879: 'insulted',
#  880: 'felt',
#  881: 'disrespected',
#  882: 'drive',
#  883: 'things',
#  884: 'exceeding',
#  885: 'hope',
#  886: 'dreamed',
#  887: 'serivce',
#  888: 'help',
#  889: 'brunch',
#  890: 'inviting',
#  891: 'lived',
#  892: '1979',
#  893: '(',
#  894: 'last',
#  895: 'stepped',
#  896: 'foot',
#  897: 'WORST',
#  898: 'EXPERIENCE',
#  899: 'Must',
#  900: 'mixed',
#  901: 'mushrooms',
#  902: 'yukon',
#  903: 'gold',
#  904: 'puree',
#  905: 'white',
#  906: 'corn',
#  907: 'beateous',
#  908: 'bug',
#  909: 'showed',
#  910: 'given',
#  911: 'climbing',
#  912: 'kitchen',
#  913: 'For',
#  914: 'waiting',
#  915: 'her',
#  916: 'soon',
#  917: 'friend',
#  918: 'tartar',
#  919: 'Wo',
#  920: 'Extremely',
#  921: 'Tasty',
#  922: 'though',
#  923: 'Soggy',
#  924: 'Jamaican',
#  925: 'mojitos',
#  926: 'Which',
#  927: 'small',
#  928: 'rich',
#  929: 'accordingly',
#  930: 'shower',
#  931: 'rinse',
#  932: 'unless',
#  933: 'mind',
#  934: 'nude',
#  935: 'see',
#  936: 'Lobster',
#  937: 'Bisque',
#  938: 'Bussell',
#  939: 'Sprouts',
#  940: 'Risotto',
#  941: 'Filet',
#  942: 'ALL',
#  943: 'needed',
#  944: 'pepper..and',
#  945: 'course',
#  946: 'none',
#  947: 'Hopefully',
#  948: 'bodes',
#  949: 'business',
#  950: 'someone',
#  951: 'cook',
#  952: 'either',
#  953: 'cold',
#  954: 'wrapped',
#  955: 'dates',
#  956: 'unbelievable',
#  957: 'BARGAIN',
#  958: 'folks',
#  959: 'Otto',
#  960: 'make',
#  961: 'welcome',
#  962: 'special',
#  963: 'As',
#  964: '``',
#  965: 'mains',
#  966: "''",
#  967: 'uninspired',
#  968: 'must-stop',
#  969: 'whenever',
#  970: 'then',
#  971: 'dealing',
#  972: 'world',
#  973: 'worst/annoying',
#  974: 'drunk',
#  975: 'fun',
#  976: 'chef',
#  977: 'Ordered',
#  978: 'double',
#  979: 'cheeseburger',
#  980: 'single',
#  981: 'patty',
#  982: 'falling',
#  983: 'apart',
#  984: 'picture',
#  985: 'uploaded',
#  986: 'Yeah',
#  987: 'couple',
#  988: 'sporting',
#  989: 'events',
#  990: 'walls',
#  991: 'covered',
#  992: 'TV',
#  993: 'possible',
#  994: 'descriptions',
#  995: 'yum',
#  996: 'eel',
#  997: 'yet',
#  998: 'mayo',
#  999: 'NONE',
#  ...}

# %%
#word_index       # 原先的參考答案.... 好怪
# Out:
# {'Wow': 5635,
#  '...': 12307,
#  'Loved': 659,
#  'this': 12524,
#  'place': 12559,
#  '.': 12675,
#  'Crust': 6,
#  'is': 12511,
#  'not': 12621,
#  'good': 12287,
#  'Not': 11837,
#  'tasty': 9618,
#  'and': 12631,
#  'the': 12673,
#  'texture': 12604,
#  'was': 12628,
#  'just': 12636,
#  'nasty': 12156,
#  'Stopped': 3567,
#  'by': 12664,
#  'during': 10854,
#  'late': 6630,
#  'May': 25,
#  'bank': 26,
#  'holiday': 27,
#  'off': 11404,
#  'Rick': 29,
#  'Steve': 30,
#  'recommendation': 8959,
#  'loved': 8829,
#  'it': 12669,
#  'The': 12625,
#  'selection': 8973,
#  'on': 11683,
#  'menu': 11961,
#  'great': 11263,
#  'so': 11622,
#  'were': 12607,
#  'prices': 9573,
#  'Now': 11015,
#  'I': 12648,
#  'am': 11726,
#  'getting': 12334,
#  'angry': 53,
#  'want': 12247,
#  'my': 12654,
#  'damn': 7472,
#  'pho': 2971,
#  'Honeslty': 61,
#  'did': 12245,
#  "n't": 12650,
#  'taste': 10068,
#  'THAT': 66,
#  'fresh': 12403,
#  ')': 12492,
#  'potatoes': 10625,
#  'like': 12325,
#  'rubber': 74,
#  'you': 12591,
#  'could': 12140,
#  'tell': 12590,
#  'they': 12658,
#  'had': 12649,
#  'been': 12365,
#  'made': 11324,
#  'up': 12276,
#  'ahead': 84,
#  'of': 12653,
#  'time': 12668,
#  'being': 11425,
#  'kept': 12345,
#  'under': 12373,
#  'a': 12571,
#  'warmer': 91,
#  'fries': 11992,
#  'too': 12311,
#  'A': 12562,
#  'touch': 2324,
#  'Service': 8756,
#  'very': 12367,
#  'prompt': 106,
#  'Would': 8750,
#  'go': 12637,
#  'back': 12623,
#  'cashier': 8714,
#  'no': 12461,
#  'care': 3862,
#  'what': 12331,
#  'ever': 12378,
#  'to': 12671,
#  'say': 11692,
#  'still': 12359,
#  'ended': 7532,
#  'wayyy': 132,
#  'overpriced': 11903,
#  'tried': 11169,
#  'Cape': 138,
#  'Cod': 139,
#  'ravoli': 140,
#  ',': 12657,
#  'chicken': 9504,
#  'with': 12539,
#  'cranberry': 145,
#  'mmmm': 147,
#  '!': 12151,
#  'disgusted': 151,
#  'because': 11613,
#  'pretty': 12306,
#  'sure': 12411,
#  'that': 12537,
#  'human': 11424,
#  'hair': 6872,
#  'shocked': 164,
#  'signs': 167,
#  'indicate': 168,
#  'cash': 169,
#  'only': 12486,
#  'Highly': 11251,
#  'recommended': 7309,
#  'Waitress': 6357,
#  'little': 12424,
#  'slow': 11830,
#  'in': 12661,
#  'service': 12194,
#  'This': 11897,
#  'worth': 11747,
#  'your': 12554,
#  'let': 7633,
#  'alone': 192,
#  'Vegas': 11376,
#  'at': 12564,
#  'all': 12434,
#  'Burrittos': 202,
#  'Blah': 203,
#  'food': 12599,
#  'amazing': 11345,
#  'also': 11943,
#  'cute': 213,
#  'less': 218,
#  'interior': 221,
#  'beautiful': 10958,
#  'So': 10642,
#  'performed': 228,
#  'That': 8796,
#  "'s": 12317,
#  'right': 9382,
#  '.the': 234,
#  'red': 1855,
#  'velvet': 236,
#  'cake': 237,
#  '..ohhh': 239,
#  'stuff': 6272,
#  '-': 11071,
#  'They': 11504,
#  'never': 10442,
#  'brought': 11505,
#  'salad': 12577,
#  'we': 12634,
#  'asked': 11646,
#  'for': 12456,
#  'hole': 257,
#  'wall': 9177,
#  'has': 12516,
#  'Mexican': 6721,
#  'street': 264,
#  'tacos': 12096,
#  'friendly': 11956,
#  'staff': 10793,
#  'Took': 271,
#  'an': 10944,
#  'hour': 10703,
#  'get': 12064,
#  'our': 12297,
#  '4': 10563,
#  'tables': 11940,
#  'restaurant': 12430,
#  'Luke': 286,
#  'warm': 11517,
#  'Our': 8699,
#  'sever': 290,
#  'running': 11396,
#  'around': 11397,
#  'he': 9927,
#  'totally': 2602,
#  'overwhelmed': 5422,
#  'worst': 10931,
#  'salmon': 10522,
#  'sashimi': 12393,
#  'Also': 11313,
#  'there': 12656,
#  'are': 12528,
#  'combos': 310,
#  'burger': 12001,
#  'beer': 9733,
#  '23': 320,
#  'which': 12468,
#  'decent': 12171,
#  'deal': 12217,
#  'final': 331,
#  'blow': 332,
#  'found': 12570,
#  'accident': 339,
#  'be': 12227,
#  'happier': 345,
#  'seems': 11797,
#  'quick': 9815,
#  'grab': 354,
#  'bite': 8884,
#  'some': 12558,
#  'familiar': 5645,
#  'pub': 360,
#  'but': 12419,
#  'do': 12211,
#  'yourself': 11433,
#  'favor': 10356,
#  'look': 10695,
#  'elsewhere': 11334,
#  'Overall': 12614,
#  'lot': 11946,
#  'redeeming': 383,
#  'quality': 10306,
#  'inexpensive': 3467,
#  'Ample': 395,
#  'portions': 10469,
#  'Poor': 401,
#  'waiter': 12024,
#  'me': 11486,
#  'feel': 11968,
#  'stupid': 412,
#  'every': 10484,
#  'came': 12538,
#  'table': 12566,
#  'My': 12026,
#  'first': 11224,
#  'visit': 10516,
#  'Hiro': 425,
#  'delight': 428,
#  'sucks': 5365,
#  'shrimp': 10670,
#  'tender': 7770,
#  'moist': 10293,
#  'There': 11481,
#  'enough': 12652,
#  'would': 12620,
#  'drag': 448,
#  'into': 2696,
#  'establishment': 9081,
#  'again': 11813,
#  'Hard': 1178,
#  'judge': 11422,
#  'whether': 458,
#  'these': 10585,
#  'sides': 6773,
#  'grossed': 5387,
#  'out': 12666,
#  'melted': 470,
#  'styrofoam': 471,
#  'eat': 12371,
#  'fear': 480,
#  'sick': 9929,
#  'On': 11081,
#  'positive': 487,
#  'note': 6017,
#  'server': 12298,
#  'attentive': 8705,
#  'provided': 496,
#  'Frozen': 500,
#  'pucks': 501,
#  'disgust': 503,
#  'people': 11305,
#  'behind': 12259,
#  'register': 513,
#  'thing': 11463,
#  'prime': 523,
#  'rib': 524,
#  'dessert': 11336,
#  'section': 527,
#  'It': 12509,
#  'bad': 12312,
#  'generic': 538,
#  'beef': 9510,
#  'cooked': 10059,
#  'If': 12092,
#  'sandwich': 12458,
#  'any': 11840,
#  'Firehouse': 559,
#  'side': 9421,
#  'Greek': 3328,
#  'dressing': 3329,
#  'pita': 8219,
#  'hummus': 9116,
#  'refreshing': 584,
#  'We': 12388,
#  'ordered': 11063,
#  'duck': 10146,
#  'rare': 8185,
#  'pink': 594,
#  'inside': 10005,
#  'nice': 10760,
#  'char': 7448,
#  'outside': 12080,
#  'He': 7188,
#  'after': 11672,
#  'us': 12569,
#  'when': 11644,
#  'realized': 2778,
#  'husband': 12027,
#  'left': 4793,
#  'his': 11008,
#  'sunglasses': 621,
#  'Their': 11271,
#  'chow': 627,
#  'mein': 628,
#  'have': 12601,
#  'horrible': 11900,
#  'attitudes': 9317,
#  'towards': 7176,
#  'customers': 647,
#  'talk': 12249,
#  'down': 12519,
#  'each': 10577,
#  'one': 11674,
#  'enjoy': 10679,
#  'their': 11909,
#  'portion': 3479,
#  'huge': 9847,
#  'servers': 12290,
#  'wonderful': 5674,
#  'imaginative': 670,
#  'Heart': 674,
#  'Attack': 675,
#  'Grill': 676,
#  'downtown': 9823,
#  'absolutely': 11153,
#  'flat-lined': 683,
#  'excuse': 3207,
#  'much': 12267,
#  'seafood': 9341,
#  '5': 9591,
#  'strings': 695,
#  'pasta': 9143,
#  'bottom': 700,
#  'amount': 12473,
#  'sauce': 11849,
#  'over': 11721,
#  'power': 714,
#  'scallop': 938,
#  'perfectly': 6082,
#  'ripped': 729,
#  'banana': 725,
#  'petrified': 732,
#  'tasteless': 11864,
#  'At': 6521,
#  'least': 11218,
#  'think': 12633,
#  'refill': 10103,
#  'water': 10102,
#  'before': 12056,
#  'struggle': 745,
#  'wave': 747,
#  '10': 5591,
#  'minutes': 12356,
#  'receives': 756,
#  'stars': 10915,
#  'APPETIZERS': 760,
#  'cocktails': 765,
#  'handmade': 768,
#  'delicious': 10046,
#  "'d": 6388,
#  'definitely': 11668,
#  'here': 12145,
#  'glad': 4358,
#  'Great': 9832,
#  'give': 10923,
#  'military': 800,
#  'discount': 801,
#  'Always': 10816,
#  'Dos': 808,
#  'Gringos': 809,
#  'Update': 811,
#  '..went': 813,
#  'second': 6886,
#  'as': 12646,
#  'got': 11496,
#  'apparently': 831,
#  'heard': 2627,
#  'salt': 12660,
#  'batter': 1104,
#  'fish': 9686,
#  'chewy': 9357,
#  'way': 11902,
#  'finish': 11631,
#  'included': 857,
#  'tastings': 859,
#  '2': 9452,
#  'drinks': 11301,
#  'Jeff': 865,
#  'went': 11333,
#  'above': 10377,
#  'beyond': 9520,
#  'expected': 8613,
#  'Really': 875,
#  'really': 12510,
#  'rice': 8158,
#  'meh': 9868,
#  'took': 12670,
#  '30': 9442,
#  'min': 4589,
#  'milkshake': 898,
#  'nothing': 11484,
#  'more': 12472,
#  'than': 12463,
#  'chocolate': 905,
#  'milk': 906,
#  'guess': 9925,
#  'should': 12600,
#  'known': 4123,
#  'suck': 12291,
#  'Excalibur': 926,
#  'use': 6022,
#  'common': 934,
#  'sense': 935,
#  'dish': 10578,
#  'quite': 12121,
#  'appalling': 942,
#  'value': 7562,
#  'well': 11092,
#  'times': 11097,
#  'Very': 11406,
#  'Bad': 10592,
#  'Customer': 953,
#  'sweet': 11880,
#  'potato': 8269,
#  'seasoned': 8924,
#  'Today': 5253,
#  "'ve": 12188,
#  'lunch': 12342,
#  'buffet': 11971,
#  'cheated': 996,
#  'wasting': 4739,
#  'eating': 8034,
#  'opportunity': 6803,
#  'going': 11733,
#  'Rice': 1005,
#  'Company': 1007,
#  'Coming': 1009,
#  'experiencing': 1013,
#  'underwhelming': 12629,
#  'relationship': 1016,
#  'where': 9371,
#  'both': 12606,
#  'parties': 1019,
#  'ca': 12588,
#  'wait': 12293,
#  'other': 8709,
#  'person': 1170,
#  'ask': 12110,
#  'break': 12084,
#  'walked': 8609,
#  'smelled': 1038,
#  'old': 8893,
#  'grease': 8670,
#  'trap': 1043,
#  'others': 8754,
#  'turkey': 1052,
#  'roast': 7918,
#  'bland': 12551,
#  'pan': 1065,
#  'cakes': 1066,
#  'everyone': 2862,
#  'raving': 1069,
#  'about': 12219,
#  'sugary': 9656,
#  'disaster': 1075,
#  'tailored': 1076,
#  'palate': 1079,
#  'six': 11038,
#  'year': 3526,
#  'love': 11671,
#  'Pho': 7753,
#  'spring': 1092,
#  'rolls': 3107,
#  'oh': 9499,
#  'yummy': 11528,
#  'try': 7233,
#  'poor': 10365,
#  'meat': 11780,
#  'ratio': 1107,
#  'tenders': 1111,
#  'unsatisfying': 1113,
#  'All': 12432,
#  'Omelets': 1128,
#  'die': 6661,
#  'Everything': 6684,
#  'In': 12575,
#  'summary': 1141,
#  'largely': 1146,
#  'disappointing': 11330,
#  'dining': 10900,
#  'experience': 12627,
#  'sexy': 1156,
#  'party': 8996,
#  'mouth': 9363,
#  "'re": 8586,
#  'outrageously': 1165,
#  'flirting': 1166,
#  'hottest': 1169,
#  'Never': 9180,
#  'Rock': 1179,
#  'Casino': 1180,
#  'WILL': 4950,
#  'NEVER': 4951,
#  'EVER': 4952,
#  'STEP': 1186,
#  'FORWARD': 1187,
#  'IN': 1188,
#  'IT': 1189,
#  'AGAIN': 1190,
#  'Best': 10389,
#  'breakfast': 11215,
#  'bye': 1200,
#  'tip': 10419,
#  'lady': 12563,
#  "'ll": 12635,
#  'Will': 9250,
#  'Food': 12405,
#  'arrived': 7549,
#  'quickly': 8621,
#  'cafe': 6529,
#  'serves': 4296,
#  'fantastic': 9908,
#  'wife': 4753,
#  'loves': 1249,
#  'roasted': 7838,
#  'garlic': 11592,
#  'bone': 1253,
#  'marrow': 1264,
#  'added': 8989,
#  'extra': 7462,
#  'meal': 12541,
#  'another': 11423,
#  'helpful': 11958,
#  'bloddy': 1283,
#  'mary': 1284,
#  'coming': 12427,
#  'Buffet': 11289,
#  'town': 9423,
#  'price': 10654,
#  'can': 11430,
#  'beat': 12413,
#  'LOVED': 6106,
#  'mussels': 1305,
#  'wine': 11764,
#  'reduction': 1310,
#  'dishes': 10786,
#  'better': 12470,
#  'buffets': 1330,
#  'Tigerlilly': 1341,
#  'afternoon': 1346,
#  'bartender': 6679,
#  'personable': 1358,
#  'AND': 4955,
#  'ambience': 9326,
#  'music': 8501,
#  'playing': 8208,
#  'next': 12641,
#  'trip': 11541,
#  'Sooooo': 1383,
#  'REAL': 1387,
#  'sushi': 10932,
#  'lovers': 2258,
#  'honest': 8918,
#  'Yama': 1396,
#  '40min': 1404,
#  'passed': 4011,
#  'between': 5788,
#  'ordering': 1409,
#  'arriving': 1413,
#  'busy': 11930,
#  'Thai': 11204,
#  'Nice': 8847,
#  'spicy': 11884,
#  'Good': 8524,
#  'Check': 1445,
#  'gross': 4377,
#  'atmosphere': 9833,
#  'Kind': 1460,
#  'hard': 12167,
#  'mess': 1464,
#  'steak': 11443,
#  'Although': 1472,
#  'liked': 6215,
#  'sound': 1480,
#  'actual': 1486,
#  'bit': 12441,
#  'know': 12315,
#  'how': 12592,
#  'managed': 1501,
#  'served': 10107,
#  'blandest': 1505,
#  'eaten': 7422,
#  'preparing': 2517,
#  'Indian': 9112,
#  'cuisine': 1516,
#  'Worst': 11203,
#  'boot': 3470,
#  'worries': 1530,
#  'fine': 6198,
#  'waitress': 11151,
#  'guys': 1542,
#  'steaks': 7305,
#  'loving': 1550,
#  'son': 1551,
#  'who': 12253,
#  'best': 11925,
#  'places': 12369,
#  'said': 12235,
#  'thought': 11920,
#  'venture': 1579,
#  'further': 1580,
#  'away': 10359,
#  'hit': 9433,
#  'spot': 11378,
#  'night': 12058,
#  'Host': 1597,
#  'lack': 1602,
#  'word': 6621,
#  'BITCHES': 1608,
#  'Bland': 9745,
#  'liking': 1614,
#  'number': 1619,
#  'reasons': 1621,
#  'waste': 10259,
#  'reviewing..': 1632,
#  'leave': 7592,
#  'Phenomenal': 1640,
#  'ambiance': 12264,
#  'return': 12379,
#  'Definitely': 5873,
#  'venturing': 1654,
#  'strip': 1657,
#  'pork': 11792,
#  'belly': 7093,
#  'will': 12183,
#  "'m": 11451,
#  'mediocre': 11705,
#  'Penne': 1682,
#  'vodka': 1683,
#  'excellent': 10945,
#  'including': 1693,
#  'massive': 1695,
#  'meatloaf': 1696,
#  'crispy': 1700,
#  'wrap': 7635,
#  'delish': 3810,
#  'tuna': 12392,
#  'melt': 9360,
#  'burgers': 11017,
#  'management': 9316,
#  'rude': 12032,
#  'Delicious': 6179,
#  'NYC': 1719,
#  'bagels': 10991,
#  'selections': 11238,
#  'cream': 11848,
#  'cheese': 7556,
#  'real': 12020,
#  'Lox': 1729,
#  'capers': 1731,
#  'even': 12036,
#  'Subway': 12465,
#  'fact': 10555,
#  'come': 5616,
#  'meet': 1752,
#  'expectations': 1754,
#  'seriously': 11381,
#  'solid': 1760,
#  'bars': 3439,
#  'extremely': 11123,
#  'many': 11390,
#  'restaurants': 11659,
#  'dine': 4026,
#  'weekend': 1797,
#  'drink': 9447,
#  'empty': 6856,
#  'suggestions': 1813,
#  'Do': 11773,
#  'or': 12115,
#  'rarely': 6248,
#  'checked': 7646,
#  'ate': 10510,
#  'disappointed': 12593,
#  'And': 11299,
#  'curry': 2257,
#  'bamboo': 1860,
#  'shoots': 1861,
#  'blanket': 1871,
#  'moz': 1873,
#  'top': 2505,
#  'i': 11411,
#  'done': 11089,
#  'cover': 1884,
#  'subpar': 1887,
#  'bathrooms': 4392,
#  'clean': 11740,
#  'itself': 11796,
#  'decorated': 4822,
#  'always': 11955,
#  'changing': 1906,
#  '&': 9584,
#  'considering': 10450,
#  '3': 7375,
#  'pace': 10507,
#  'thumbs': 9858,
#  'watched': 10792,
#  'pay': 10724,
#  'attention': 1958,
#  'ignore': 1963,
#  'fiancé': 1967,
#  'middle': 1973,
#  'day': 10593,
#  'greeted': 7956,
#  'seated': 8007,
#  'Mandalay': 1993,
#  'Bay': 12438,
#  'waited': 7318,
#  'forty': 1999,
#  'five': 2000,
#  'vain': 2003,
#  'Crostini': 2005,
#  'stale': 9501,
#  'Some': 10710,
#  'highlights': 2015,
#  ':': 11987,
#  'nigiri': 2019,
#  'joint': 8022,
#  'different': 11083,
#  'cut': 11403,
#  'piece': 11102,
#  's': 2049,
#  'flavored': 2053,
#  'Voodoo': 2058,
#  'since': 10486,
#  'gluten': 2074,
#  'free': 2075,
#  'several': 7129,
#  'years': 7652,
#  'ago': 7653,
#  'Unfortunately': 12270,
#  'must': 11213,
#  'bakery': 6528,
#  'leftover': 2094,
#  'everything': 10833,
#  'STALE': 2101,
#  'today': 6804,
#  'relocated': 2109,
#  'impressed': 12618,
#  'immediately': 12234,
#  'diverse': 2123,
#  'reasonably': 2126,
#  'priced': 6490,
#  'Avoid': 2129,
#  'cost': 2132,
#  'Restaurant': 2134,
#  'full': 11765,
#  'DELICIOUS': 2143,
#  'hands-down': 2149,
#  'Phoenix': 9544,
#  'metro': 2160,
#  'area': 7390,
#  'if': 12647,
#  'looking': 12346,
#  'treated': 4580,
#  'Bacon': 2184,
#  'hella': 2186,
#  'salty': 2187,
#  'spinach': 2193,
#  'avocado': 2195,
#  'ingredients': 2199,
#  'sad': 11409,
#  'literally': 12495,
#  'zero': 6766,
#  'used': 11026,
#  'menus': 2225,
#  'handed': 2226,
#  'ladies': 5041,
#  'listed': 2234,
#  'waitresses': 2237,
#  'Lordy': 2242,
#  'Khao': 2245,
#  'Soi': 2246,
#  'missed': 2255,
#  'terrific': 2265,
#  'thrilled': 2270,
#  'accommodations': 2275,
#  'vegetarian': 9289,
#  'daughter': 2279,
#  'Perhaps': 2281,
#  'caught': 2283,
#  'them': 9667,
#  'judging': 2289,
#  'reviews': 12138,
#  'inspired': 2299,
#  'leaves': 2307,
#  'desired': 2312,
#  'modern': 2317,
#  'hip': 2319,
#  'while': 12085,
#  'maintaining': 2322,
#  'coziness': 2326,
#  'weekly': 2330,
#  'haunt': 2331,
#  'once': 11219,
#  'sat': 10965,
#  '20': 11127,
#  'asking': 2357,
#  'take': 8309,
#  'order': 11308,
#  'flavor': 12602,
#  'overcooked': 10032,
#  'charcoal': 10062,
#  'decided': 6896,
#  'send': 2393,
#  'looked': 5419,
#  'she': 12029,
#  'verge': 2405,
#  'having': 2407,
#  'heart': 11629,
#  'attack': 2410,
#  'dressed': 2413,
#  'rudely': 2419,
#  'probably': 10737,
#  'dirt': 9536,
#  'Love': 5989,
#  'hits': 2430,
#  'something': 11516,
#  'healthy': 10853,
#  'lacking': 12608,
#  'quantity': 2442,
#  'Lemon': 2449,
#  'raspberry': 2450,
#  'ice': 12496,
#  'cocktail': 2452,
#  'incredible': 6408,
#  'sucked': 12300,
#  'imagined': 2473,
#  'Interesting': 2475,
#  'decor': 9172,
#  'What': 12302,
#  'crepe': 2485,
#  'station': 6243,
#  'hot': 11995,
#  'bread': 11274,
#  'butter': 11283,
#  'home': 8481,
#  'chips': 11339,
#  'bacon': 9465,
#  'bits': 2503,
#  '.very': 2507,
#  'original': 2508,
#  'watch': 3049,
#  'Both': 9579,
#  'egg': 4299,
#  'When': 12479,
#  'gyros': 2539,
#  'missing': 2541,
#  'wings': 7473,
#  'feeling': 9259,
#  'satisfied': 2561,
#  'Joey': 2569,
#  'voted': 2572,
#  'dog': 9876,
#  'Valley': 8734,
#  'readers': 2580,
#  'Magazine': 2583,
#  'bowl': 5018,
#  'live': 12572,
#  'Fridays': 2601,
#  'blows': 2603,
#  'insulted': 11413,
#  'felt': 11412,
#  'disrespected': 11415,
#  'drive': 7779,
#  'things': 7355,
#  'exceeding': 2636,
#  'hope': 11490,
#  'dreamed': 2642,
#  'serivce': 2652,
#  'help': 2659,
#  'brunch': 8465,
#  'inviting': 2669,
#  'lived': 2678,
#  '1979': 2681,
#  '(': 12483,
#  'last': 10515,
#  'stepped': 2694,
#  'foot': 2695,
#  'WORST': 2701,
#  'EXPERIENCE': 2702,
#  'Must': 2705,
#  'mixed': 2720,
#  'mushrooms': 2721,
#  'yukon': 2723,
#  'gold': 2724,
#  'puree': 10225,
#  'white': 10223,
#  'corn': 2728,
#  'beateous': 2730,
#  'bug': 2757,
#  'showed': 2736,
#  'given': 3401,
#  'climbing': 2759,
#  'kitchen': 2762,
#  'For': 10858,
#  'waiting': 9063,
#  'her': 12576,
#  'soon': 12353,
#  'friend': 7707,
#  'tartar': 2793,
#  'Wo': 10298,
#  'Extremely': 2800,
#  'Tasty': 2801,
#  'though': 10175,
#  'Soggy': 2808,
#  'Jamaican': 2814,
#  'mojitos': 2815,
#  'Which': 2819,
#  'small': 10472,
#  'rich': 2832,
#  'accordingly': 2835,
#  'shower': 2852,
#  'rinse': 2846,
#  'unless': 4968,
#  'mind': 4117,
#  'nude': 2860,
#  'see': 11570,
#  'Lobster': 9905,
#  'Bisque': 4757,
#  'Bussell': 2876,
#  'Sprouts': 2877,
#  'Risotto': 2879,
#  'Filet': 8875,
#  'ALL': 2882,
#  'needed': 10100,
#  'pepper..and': 2886,
#  'course': 10896,
#  'none': 4503,
#  'Hopefully': 2896,
#  'bodes': 2898,
#  'business': 11617,
#  'someone': 12093,
#  'cook': 11441,
#  'either': 10683,
#  'cold': 12497,
#  'wrapped': 2931,
#  'dates': 2932,
#  'unbelievable': 2937,
#  'BARGAIN': 2938,
#  'folks': 7279,
#  'Otto': 2943,
#  'make': 12169,
#  'welcome': 2949,
#  'special': 9271,
#  'As': 9040,
#  '``': 12229,
#  'mains': 2957,
#  "''": 12231,
#  'uninspired': 2961,
#  'must-stop': 2985,
#  'whenever': 2986,
#  'then': 12004,
#  'dealing': 10819,
#  'world': 9128,
#  'worst/annoying': 3010,
#  'drunk': 3011,
#  'fun': 8748,
#  'chef': 8950,
#  'Ordered': 7944,
#  'double': 8369,
#  'cheeseburger': 8370,
#  'single': 10088,
#  'patty': 3027,
#  'falling': 3030,
#  'apart': 3031,
#  'picture': 3033,
#  'uploaded': 3034,
#  'Yeah': 3036,
#  'couple': 7651,
#  'sporting': 3053,
#  'events': 3054,
#  'walls': 3057,
#  'covered': 3059,
#  'TV': 3061,
#  'possible': 12162,
#  'descriptions': 3080,
#  'yum': 3084,
#  'eel': 3091,
#  'yet': 12358,
#  'mayo': 8491,
#  'NONE': 3104,
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    '''創建一個vector'''
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            index = word_index[word]
            vector[index] += 1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])
